# %% [markdown]
# <a href="https://colab.research.google.com/github/Katia1697/PyE/blob/main/Unidad/COVID016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y Estadistica
# ##Unidad 1
# Actividad 6: COVID
#
# Alumna: Katia Saucedo Perez
#
# Profesor: Jose Gabriel Rodriguez Rivas
#
# Grupo: 2YY
#
# Fecha: 18/02/2025

# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from matplotlib import pyplot

# %%
#cargar el archivo CSV en una variable llamada covid
covid= pd.read_csv("covid.csv", encoding= "ISO-8859-1")

# %%
covid.head()
# Out:
#    ï»¿ORIGEN  SECTOR    SEXO ENTIDAD_NAC  TIPO_PACIENTE FECHA_INGRESO  \
# 0          1       4  Hombre   Zacatecas  Hospitalizado    27/03/2020
# 1          1      12  Hombre   Zacatecas  Hospitalizado    06/04/2020
# 2          1      12   Mujer   Zacatecas  Hospitalizado    15/04/2020
# 3          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
# 4          2      12   Mujer   Zacatecas  Hospitalizado    08/05/2020
#
#   FECHA_SINTOMAS   FECHA_DEF INTUBADO NEUMONIA  ...  EPOC ASMA INMUSUPR  \
# 0     27/03/2020  9999-99-99       No       No  ...    No   No       No
# 1     02/04/2020  9999-99-99       No       Si  ...    No   No       No
# 2     12/04/2020  9999-99-99       No       Si  ...    No   No       Si
# 3     08/05/2020  9999-99-99       Si       No  ...    No   No       No
# 4     08/05/2020  9999-99-99       Si       No  ...    No   No       No
#
#   HIPERTENSION CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO RESULTADO UCI
# 0           No             No       No            No         No  Negativo  No
# 1           No             No       No            No         No  Negativo  No
# 2           No             No       No            No         No  Negativo  No
# 3           No             No       No            No         No  Negativo  Si
# 4           No             No       No            No         No  Negativo  Si
#
# [5 rows x 23 columns]

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23677 entries, 0 to 23676
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿ORIGEN       23677 non-null  int64
#  1   SECTOR          23677 non-null  int64
#  2   SEXO            23677 non-null  object
#  3   ENTIDAD_NAC     23677 non-null  object
#  4   TIPO_PACIENTE   23677 non-null  object
#  5   FECHA_INGRESO   23677 non-null  object
#  6   FECHA_SINTOMAS  23677 non-null  object
#  7   FECHA_DEF       23677 non-null  object
#  8   INTUBADO        23677 non-null  object
#  9   NEUMONIA        23677 non-null  object
#  10  EDAD            23677 non-null  int64
#  11  EMBARAZO        23677 non-null  object
#  12  DIABETES        23677 non-null  object
#  13  EPOC            23677 non-null  object
#  14  ASMA            23677 non-null  object
#  15  INMUSUPR        23677 non-null  object
#  16  HIPERTENSION    23677 non-null  object
#  17  CARDIOVASCULAR  23677 non-null  object
#  18  OBESIDAD        23677 non-null  object
#  19  RENAL_CRONICA   23677 non-null  object
#  20  TABAQUISMO      23677 non-null  object
#  21  RESULTADO       23676 non-null  object
#  22  UCI             23676 non-null  object
# dtypes: int64(3), object(20)
# memory usage: 4.2+ MB

# %%
#Mostrar la edad maxima de la base de datos de la columna edad
covid.EDAD.max()
# Out:
# 19

# %%
#Mostrar la edad minima de la base de datos de la columna edad
covid.EDAD.min()
# Out:
# 0

# %%
#Mostrar los datos estadisticos descriptivos de la columna edad
covid.EDAD.describe()
# Out:
# count    23677.000000
# mean         9.759049
# std          6.372001
# min          0.000000
# 25%          4.000000
# 50%         10.000000
# 75%         16.000000
# max         19.000000
# Name: EDAD, dtype: float64

# %%
#Histograma
media=covid.EDAD.mean()

plt.pyplot.hist(covid.EDAD, bins=11)
plt.pyplot.title("Histograma Edad Pruebas COVID")
plt.pyplot.axvline(media, color='y',linestyle='dashed', linewidth=2, label=f'Media={media:.2f}')
plt.pyplot.xlabel("Edad")
plt.pyplot.ylabel("Frecuencias")
# Out:
# Text(0, 0.5, 'Frecuencias')

# %%
#Dibujar el histograma de la columna de sexo, esto permite comparar cuantos hay de cada grupo
plt.pyplot.hist(covid.SEXO, bins=3)

#Establece las etiquetas x/y y muestra el titulo
plt.pyplot.title("Histograma Sexo de Pruebas COVID")
plt.pyplot.xlabel("Sexo")
plt.pyplot.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.pyplot.hist(covid.TIPO_PACIENTE, bins=3)

#Establece las etiquetas x/y y muestra el titulo
plt.pyplot.title("Histograma de tipos Pacientes en Pruebas COVID")
plt.pyplot.xlabel("Tipo Paciente")
plt.pyplot.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
sns.boxplot(x="SEXO", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='SEXO', ylabel='EDAD'>

# %%
sns.boxplot(x="TIPO_PACIENTE", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='TIPO_PACIENTE', ylabel='EDAD'>

# %%
sns.boxplot(x="RESULTADO", y="EDAD", data=covid)
# Out:
# <Axes: xlabel='RESULTADO', ylabel='EDAD'>
