# %% [markdown]
# <a href="https://colab.research.google.com/github/Katia1697/PyE/blob/main/Unidad/Practica%204%20y%205.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y Estadistica
# ##Unidad 1
# ##PRACTICA 4
# TABLAS DE FRECUENCIAS
#
# Alumna: Katia Saucedo Perez
#
# Profesor: Jose Gabriel Rodriguez Rivas
#
# Grupo: 2YY
#
# Fecha: 11/02/2025

# %%
import random

# %%
# basado en el Libro estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas

edades=[]

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
  numero_aleatorio = random.randint( 18, 70)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)

print(edades)
# Out:
# [56, 41, 28, 56, 42, 57, 44, 55, 19, 47, 46, 19, 51, 22, 51, 26, 45, 62, 65, 27, 67, 67, 51, 48, 21, 59, 26, 35, 30, 46, 69, 48, 22, 63, 36, 69, 32, 20, 61, 67, 18, 68, 62, 33, 70, 44, 69, 52, 48, 41, 53, 60, 48, 53, 64, 57, 18, 33, 18, 18, 30, 20, 33, 44, 61, 50, 69, 43, 51, 30, 44, 32, 70, 27, 53, 59, 68, 62, 36, 51, 61, 57, 42, 49, 39, 70, 29, 21, 57, 37, 19, 42, 20, 52, 32, 24, 48, 30, 38, 62]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los numeros aleatorios
df= pd.DataFrame(edades,columns=['Edad'])
df.head() #El numero entre () indica el numero de filas a mostrar
# Out:
#    Edad
# 0    56
# 1    41
# 2    28
# 3    56
# 4    42

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias= df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias= tabla_frecuencias.sort_values(by='Edad')

#Imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edad  Frecuencia
# 4     18           4
# 8     19           3
# 13    20           3
# 22    21           2
# 25    22           2
# 30    24           1
# 24    26           2
# 23    27           2
# 39    28           1
# 32    29           1
# 5     30           4
# 14    32           3
# 10    33           3
# 28    35           1
# 20    36           2
# 31    37           1
# 44    38           1
# 33    39           1
# 18    41           2
# 12    42           3
# 35    43           1
# 2     44           4
# 41    45           1
# 26    46           2
# 40    47           1
# 1     48           5
# 34    49           1
# 29    50           1
# 0     51           5
# 17    52           2
# 16    53           3
# 36    55           1
# 21    56           2
# 6     57           4
# 27    59           2
# 38    60           1
# 11    61           3
# 3     62           4
# 43    63           1
# 37    64           1
# 42    65           1
# 15    67           3
# 19    68           2
# 7     69           4
# 9     70           3

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 4     18           4           0.04
# 8     19           3           0.03
# 13    20           3           0.03
# 22    21           2           0.02
# 25    22           2           0.02
# 30    24           1           0.01
# 24    26           2           0.02
# 23    27           2           0.02
# 39    28           1           0.01
# 32    29           1           0.01
# 5     30           4           0.04
# 14    32           3           0.03
# 10    33           3           0.03
# 28    35           1           0.01
# 20    36           2           0.02
# 31    37           1           0.01
# 44    38           1           0.01
# 33    39           1           0.01
# 18    41           2           0.02
# 12    42           3           0.03
# 35    43           1           0.01
# 2     44           4           0.04
# 41    45           1           0.01
# 26    46           2           0.02
# 40    47           1           0.01
# 1     48           5           0.05
# 34    49           1           0.01
# 29    50           1           0.01
# 0     51           5           0.05
# 17    52           2           0.02
# 16    53           3           0.03
# 36    55           1           0.01
# 21    56           2           0.02
# 6     57           4           0.04
# 27    59           2           0.02
# 38    60           1           0.01
# 11    61           3           0.03
# 3     62           4           0.04
# 43    63           1           0.01
# 37    64           1           0.01
# 42    65           1           0.01
# 15    67           3           0.03
# 19    68           2           0.02
# 7     69           4           0.04
# 9     70           3           0.03

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 4     18           4           0.04              4.0
# 8     19           3           0.03              3.0
# 13    20           3           0.03              3.0
# 22    21           2           0.02              2.0
# 25    22           2           0.02              2.0
# 30    24           1           0.01              1.0
# 24    26           2           0.02              2.0
# 23    27           2           0.02              2.0
# 39    28           1           0.01              1.0
# 32    29           1           0.01              1.0
# 5     30           4           0.04              4.0
# 14    32           3           0.03              3.0
# 10    33           3           0.03              3.0
# 28    35           1           0.01              1.0
# 20    36           2           0.02              2.0
# 31    37           1           0.01              1.0
# 44    38           1           0.01              1.0
# 33    39           1           0.01              1.0
# 18    41           2           0.02              2.0
# 12    42           3           0.03              3.0
# 35    43           1           0.01              1.0
# 2     44           4           0.04              4.0
# 41    45           1           0.01              1.0
# 26    46           2           0.02              2.0
# 40    47           1           0.01              1.0
# 1     48           5           0.05              5.0
# 34    49           1           0.01              1.0
# 29    50           1           0.01              1.0
# 0     51           5           0.05              5.0
# 17    52           2           0.02              2.0
# 16    53           3           0.03              3.0
# 36    55           1           0.01              1.0
# 21    56           2           0.02              2.0
# 6     57           4           0.04              4.0
# 27    59           2           0.02              2.0
# 38    60           1           0.01              1.0
# 11    61           3           0.03              3.0
# 3     62           4           0.04              4.0
# 43    63           1           0.01              1.0
# 37    64           1           0.01              1.0
# 42    65           1           0.01              1.0
# 15    67           3           0.03              3.0
# 19    68           2           0.02              2.0
# 7     69           4           0.04              4.0
# 9     70           3           0.03              3.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum() #Cumsum para calcular la suma acomulada
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 4     18           4           0.04              4.0               4
# 8     19           3           0.03              3.0               7
# 13    20           3           0.03              3.0              10
# 22    21           2           0.02              2.0              12
# 25    22           2           0.02              2.0              14
# 30    24           1           0.01              1.0              15
# 24    26           2           0.02              2.0              17
# 23    27           2           0.02              2.0              19
# 39    28           1           0.01              1.0              20
# 32    29           1           0.01              1.0              21
# 5     30           4           0.04              4.0              25
# 14    32           3           0.03              3.0              28
# 10    33           3           0.03              3.0              31
# 28    35           1           0.01              1.0              32
# 20    36           2           0.02              2.0              34
# 31    37           1           0.01              1.0              35
# 44    38           1           0.01              1.0              36
# 33    39           1           0.01              1.0              37
# 18    41           2           0.02              2.0              39
# 12    42           3           0.03              3.0              42
# 35    43           1           0.01              1.0              43
# 2     44           4           0.04              4.0              47
# 41    45           1           0.01              1.0              48
# 26    46           2           0.02              2.0              50
# 40    47           1           0.01              1.0              51
# 1     48           5           0.05              5.0              56
# 34    49           1           0.01              1.0              57
# 29    50           1           0.01              1.0              58
# 0     51           5           0.05              5.0              63
# 17    52           2           0.02              2.0              65
# 16    53           3           0.03              3.0              68
# 36    55           1           0.01              1.0              69
# 21    56           2           0.02              2.0              71
# 6     57           4           0.04              4.0              75
# 27    59           2           0.02              2.0              77
# 38    60           1           0.01              1.0              78
# 11    61           3           0.03              3.0              81
# 3     62           4           0.04              4.0              85
# 43    63           1           0.01              1.0              86
# 37    64           1           0.01              1.0              87
# 42    65           1           0.01              1.0              88
# 15    67           3           0.03              3.0              91
# 19    68           2           0.02              2.0              93
# 7     69           4           0.04              4.0              97
# 9     70           3           0.03              3.0             100

# %% [markdown]
# #Regla de Struges
# 1.Es una regla que sirve para calcular el numero de clases o intervalos idoneo en los que se debe dividir un conjunto de datos.
# 2.Establece que un numero de clases es igual a uno mas el logratimos en vase dos del numero total de datos.
# c=1+log2(N)
# donde N es el tamaño de la muestra

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
# Volvemos a usar la lista de edades
print(edades)
# Out:
# [56, 41, 28, 56, 42, 57, 44, 55, 19, 47, 46, 19, 51, 22, 51, 26, 45, 62, 65, 27, 67, 67, 51, 48, 21, 59, 26, 35, 30, 46, 69, 48, 22, 63, 36, 69, 32, 20, 61, 67, 18, 68, 62, 33, 70, 44, 69, 52, 48, 41, 53, 60, 48, 53, 64, 57, 18, 33, 18, 18, 30, 20, 33, 44, 61, 50, 69, 43, 51, 30, 44, 32, 70, 27, 53, 59, 68, 62, 36, 51, 61, 57, 42, 49, 39, 70, 29, 21, 57, 37, 19, 42, 20, 52, 32, 24, 48, 30, 38, 62]

# %%
#Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     56
# 1     41
# 2     28
# 3     56
# 4     42
# ..   ...
# 95    24
# 96    48
# 97    30
# 98    38
# 99    62
#
# [100 rows x 1 columns]

# %%
#Calcular el  numero de intervalos utilizando la regal de Sturges
n = len(edades)
K = int(1+math.log2(100))
print("Valor de N = igual ", n, " \nNumero de intervalos =", K)
# Out:
# Valor de N = igual  100
# Numero de intervalos = 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia=pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (47.714, 55.143]    18
# 1  (55.143, 62.571]    16
# 2  (17.947, 25.429]    15
# 3    (62.571, 70.0]    15
# 4  (40.286, 47.714]    14
# 5  (25.429, 32.857]    13
# 6  (32.857, 40.286]     9

# %%
#Ordenar la tabla de frecuencia
tabla_frecuencia=tabla_frecuencia.sort_values(by='Clase') #sort es para ordenar
tabla_frecuencia
# Out:
#               Clase  Frec
# 2  (17.947, 25.429]    15
# 5  (25.429, 32.857]    13
# 6  (32.857, 40.286]     9
# 4  (40.286, 47.714]    14
# 0  (47.714, 55.143]    18
# 1  (55.143, 62.571]    16
# 3    (62.571, 70.0]    15

# %%
#Generar columnas siguientes
tabla_frecuencia['Frec Rel']=tabla_frecuencia['Frec']/n
tabla_frecuencia['Frec Porc']=tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac']=tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac']=tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac']=tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 2  (17.947, 25.429]    15      0.15       15.0       15         0.15
# 5  (25.429, 32.857]    13      0.13       13.0       28         0.28
# 6  (32.857, 40.286]     9      0.09        9.0       37         0.37
# 4  (40.286, 47.714]    14      0.14       14.0       51         0.51
# 0  (47.714, 55.143]    18      0.18       18.0       69         0.69
# 1  (55.143, 62.571]    16      0.16       16.0       85         0.85
# 3    (62.571, 70.0]    15      0.15       15.0      100         1.00
#
#    Frec Porc Ac
# 2          15.0
# 5          28.0
# 6          37.0
# 4          51.0
# 0          69.0
# 1          85.0
# 3         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histrograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histrograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
#crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5) #Sturges (bins) cuantos serian los contenedores a usar de acuerdo a lo que estamos usando
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #Practica 5
# ## Diagrama de Caja y Bigotes

# %%
edades2=[]

#Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
  numero_aleatorio = random.randint( 20, 87)
  #Agregamos el numero aleatorio a la lista de valores
  edades2.append(numero_aleatorio)

print(edades2)
# Out:
# [25, 37, 31, 25, 60, 83, 80, 31, 83, 29, 50, 35, 41, 30, 29, 78, 29, 38, 84, 39, 23, 53, 46, 22, 87, 86, 81, 75, 78, 82, 82, 66, 23, 64, 60, 58, 84, 60, 51, 25, 48, 72, 28, 78, 68, 80, 73, 61, 25, 52, 37, 61, 32, 33, 61, 53, 40, 81, 34, 77, 60, 82, 84, 38, 78, 33, 51, 22, 57, 42, 82, 74, 86, 23, 27, 24, 71, 21, 64, 30, 86, 37, 75, 26, 81, 83, 72, 86, 61, 55, 24, 79, 66, 58, 56, 29, 67, 72, 58, 21]

# %%
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1= ax1.boxplot(edades,
                    vert=True, #vertical box alignment
                    patch_artist= True) #fill whit color
ax1.set_title('Edades Encuesta 1')
bplot2= ax2.boxplot(edades2,
                    vert=True, #vertical box alignment
                    patch_artist= True) #fill whit color
ax2.set_title('Edades Encuesta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2)= plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1= ax1.boxplot(edades,
                    vert=True, #vertical box alignment
                    patch_artist= True) #fill whit color
ax1.set_title('Edades Encuesta 1')
bplot2= ax2.boxplot(edades2,
                    vert=True, #vertical box alignment
                    patch_artist= True) #fill whit color
ax2.set_title('Edades Encuesta 2')
plt.show()
