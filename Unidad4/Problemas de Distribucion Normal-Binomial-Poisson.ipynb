# %% [markdown]
# <a href="https://colab.research.google.com/github/Katia1697/PyE/blob/main/Unidad4/Problemas%20de%20Distribucion%20Normal-Binomial-Poisson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# #Probabilidad y Estadistica
# ##Unidad 4
# Actividad: Problemas de Distribución Normal, Binomial y Poisson en Python
#
# Alumna: Katia Saucedo Perez
#
# Profesor: Jose Gabriel Rodriguez Rivas
#
# Grupo: 2YY
#
# Fecha: 11/04/2025

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Generar datos para la distribucion normal

media = 70 # Media
desv_std =4 # Desviacion estandar
num_datos = 500

#generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50] # Mostrar los primeros 50
# Out:
# array([73.64322176, 69.02148587, 65.94141158, 70.74158402, 66.62842554,
#        70.55143545, 65.14390191, 65.97126696, 68.24081001, 73.24849778,
#        70.17357617, 74.3686261 , 66.43982499, 71.99490862, 64.23620908,
#        72.38497604, 71.05794669, 73.50982867, 73.13021184, 67.61545692,
#        70.82453729, 67.65481206, 72.85086267, 67.90419923, 72.35425346,
#        73.08645497, 69.39928196, 75.52125652, 73.38874167, 65.06642652,
#        76.22644121, 62.54384876, 67.29443238, 66.78015585, 72.77250961,
#        67.39979402, 65.28579499, 65.13698346, 70.53566135, 70.39776557,
#        64.18841967, 69.36394613, 72.70091005, 69.27951569, 68.42856848,
#        75.86915199, 67.2274151 , 70.52017884, 66.90365906, 70.40394834])

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b') #Histograma de los datos
plt.title('Distribucion Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
# # Crear un rango de valores para crear una densidad
x = np.linspace(media -  3 * desv_std, media + 3 *desv_std, num_datos)

# Calcular la PDF de la distribucion normal
pdf = 1 / (desv_std * np.sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **2))

# %%
pdf.size, num_datos
# Out:
# (500, 500)

# %%
# Para no imprimir toda la lista de valores (500), desplegamos los primeros 50
print("Imprimir los primeros 50 Valores de x", x[0:50], " , y los imprimeros 50 pdf", pdf[0:50])
# Out:
# Imprimir los primeros 50 Valores de x [58.         58.04809619 58.09619238 58.14428858 58.19238477 58.24048096
#  58.28857715 58.33667335 58.38476954 58.43286573 58.48096192 58.52905812
#  58.57715431 58.6252505  58.67334669 58.72144289 58.76953908 58.81763527
#  58.86573146 58.91382766 58.96192385 59.01002004 59.05811623 59.10621242
#  59.15430862 59.20240481 59.250501   59.29859719 59.34669339 59.39478958
#  59.44288577 59.49098196 59.53907816 59.58717435 59.63527054 59.68336673
#  59.73146293 59.77955912 59.82765531 59.8757515  59.9238477  59.97194389
#  60.02004008 60.06813627 60.11623246 60.16432866 60.21242485 60.26052104
#  60.30861723 60.35671343]  , y los imprimeros 50 pdf [0.00110796 0.00114858 0.0011905  0.00123379 0.00127846 0.00132455
#  0.00137211 0.00142118 0.00147178 0.00152397 0.00157777 0.00163325
#  0.00169042 0.00174935 0.00181007 0.00187262 0.00193706 0.00200342
#  0.00207176 0.00214212 0.00221455 0.0022891  0.00236581 0.00244475
#  0.00252595 0.00260947 0.00269536 0.00278367 0.00287447 0.0029678
#  0.00306371 0.00316227 0.00326352 0.00336753 0.00347436 0.00358405
#  0.00369667 0.00381228 0.00393094 0.00405271 0.00417764 0.0043058
#  0.00443725 0.00457205 0.00471027 0.00485197 0.0049972  0.00514604
#  0.00529854 0.00545478]

# %%
# Visualizar la PDF
plt.figure(figsize=(6,4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std,2 )))
plt.title('Funcion de Densidad de Probabilidad (PDF) - Distribucion Normal')
plt.xlabel('Pesos en Kg. de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar histograma
plt.figure(figsize=(6,4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribucion Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))

# Parametros de la distribucion normal
media = 70 # Media
desv_std = 4 # Desviacion estandar
total_estudiantes = 500

#VARIABLE para Calculo de la probabilidad de que un estudiante que pese menos de 75 kg
peso_limite = 79

#Primero necesitamos calcular la probabilidad de que un estudiante peso menos
# de 75 kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_75kg = norm.cdf(peso_limite, media, desv_std)

#densidad_1 = 1 / (desv_std * np,sqrt(2 * np.pi)) * np.exp(-(x - media)**2 / (2 * desv_std **))

#Calculo del numero de estudiantes que pesan menos de 75 kg
estudiantes_menos_75kg = total_estudiantes * prob_menos_75kg

print("Probabilidad de que un estudiante pese menos de 75 kg:", prob_menos_75kg)
print("Numero de estudiantes que pesan menos de 75 kg:", estudiantes_menos_75kg)

#Graficar la distribucion normal
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 1000)
y = norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 75 kg. \n $\mu=70$, $\sigma=4$, x=500')
plt.xlabel('Peso(kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 75 kg: 0.9877755273449553
# Numero de estudiantes que pesan menos de 75 kg: 493.88776367247766

# %%
plt.figure(figsize=(6,4))
#Parametros de la distribucion normal
media = 70 #Media
desv_std = 4 # Desviacion estandar
total_estudiantes = 500

#VARIABLE para Calculo de la probabilidad de que un estudiante pese menos de 75kg
peso_limite = 62

# Primero necesitamos calcular la probabilidad de que un estudiante pese menos
# de 75 kg utilizando la funcion de distribucion acumulativa (CDF) de la distribucion normal
prob_menos_62kg = norm.cdf(peso_limite, media, desv_std)

#Calculo del numero de estudiantes que pesan menos de 75 kg
estudiantes_menos_62kg = total_estudiantes * prob_menos_62kg

print("Probabilidad de que un estudiante pese menos de 62 kg: ", prob_menos_62kg)
print("Numero de estudiantes que pesan menos de 75 kg: ", estudiantes_menos_62kg)

#Calcular la distribucion normal
x=np.linspace(media - 4 * desv_std, media +4 * desv_std, total_estudiantes)
y=norm.pdf(x, media, desv_std)

#Graficar la distribucion normal
plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x <= peso_limite), color='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese menos de 62 kg, \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
plt.show()
# Out:
# Probabilidad de que un estudiante pese menos de 62 kg:  0.022750131948179195
# Numero de estudiantes que pesan menos de 75 kg:  11.375065974089598

# %%
plt.figure(figsize=(6,4))

# Parametros de la distribucion normal
media = 70 # Media
desv_std = 4 #Desviacion estandar
peso_limite=79 # Peso Limite
total_estudiantes = 500

# Calculamos la probabilidad de qie im estudiante pese menos o igual a 79 kg
prob_menos_79kg = norm.cdf(peso_limite, media, desv_std)

# La probabilidad de que un estudiante pese mas de 79 kg es complementaria
prob_mas_79kg = 1 - prob_menos_79kg

# Calculamos el numero aproximado de estudiantes que pesan mas de 79 kg
estudiantes_mas_79kg = total_estudiantes * prob_mas_79kg

print("Probabilidad de que un estudiante pese mas de 79 kg: ", prob_mas_79kg)
print("Numero aproximado de estudiantes que pesan mas de 79 kg: ", estudiantes_mas_79kg)

# Calcular la funcion de densidad de probabilidad de la distibucion normal
x=np.linspace(media - 4 * desv_std, media + 4 * desv_std, total_estudiantes)
y=norm.pdf(x, media, desv_std)

plt.plot(x, y, 'b', linewidth=2)
plt.fill_between(x, y, where=(x >= peso_limite), color ='skyblue', alpha=0.5)
plt.title('Probabilidad de que un estudiante pese mas de 79 kg. \n $\mu=70$, $\sigma=4$, X=500')
plt.xlabel('Peso (kg)')
plt.ylabel('Densidad de probabilidad')
plt.grid(True)
# Out:
# Probabilidad de que un estudiante pese mas de 79 kg:  0.012224472655044671
# Numero aproximado de estudiantes que pesan mas de 79 kg:  6.112236327522336

# %% [markdown]
# #Binomial#

# %% [markdown]
# # Ejercicio 1 #

# %%
from scipy.stats import binom

probabilidad_exito = 0.83
num_pacientes = 16
X = 16

probabilidad_ninguno_enfermo = binom.pmf( X, num_pacientes, probabilidad_exito)

print("La probabilidad de que ningun paciente sufra la enfermedad es: ", probabilidad_ninguno_enfermo)
# Out:
# La probabilidad de que ningun paciente sufra la enfermedad es:  0.0507282029895386

# %%
from scipy.stats import binom

probabilidad_exito = 0.83
num_pacientes = 16
X = 0

probabilidad_todos_enfermos = binom.pmf(X, num_pacientes, probabilidad_exito)

print("La probabilidad de que todos los pacientes sufran la enfermedad es: ", probabilidad_todos_enfermos)
# Out:
# La probabilidad de que todos los pacientes sufran la enfermedad es:  4.866119187566701e-13

# %% [markdown]
# ## Ejercicio 2 ##

# %%
from scipy.stats import binom

n = 10
p = 0.1
x = 2

probabilidad_x_2 = binom.pmf(x, n, p)

print("La probabilidad de que la variable aleatoria X sea igual a 2 es: ",probabilidad_x_2)
# Out:
# La probabilidad de que la variable aleatoria X sea igual a 2 es:  0.19371024450000007

# %% [markdown]
# # Ejercicio 3 #

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

n = 10
p = 0.10

valores_x= np.arange(0, n+1)
probabilidades_x = [binom.pmf(x, n, p) for x in valores_x]

print("Valores de x\t probabilidades")
for x, probabilidad in zip(valores_x, probabilidades_x):
  print(f"{x}\t\t{probabilidad}")
# Out:
# Valores de x	 probabilidades
# 0		0.34867844009999993
# 1		0.38742048899999965
# 2		0.19371024450000007
# 3		0.05739562799999998
# 4		0.01116026100000001
# 5		0.0014880347999999995
# 6		0.00013778100000000007
# 7		8.748000000000003e-06
# 8		3.6449999999999996e-07
# 9		8.999999999999995e-09
# 10		1.0000000000000006e-10

# %%
# Graficar el histograma de la distribución binomial
plt.figure(figsize=(8, 6))
plt.bar(valores_x, probabilidades_x, color='skyblue')
plt.title('Distribución Binomial')
plt.xlabel('Valor de X')
plt.ylabel('Probabilidad')
plt.xticks(valores_x)
plt.grid(True)
plt.show()

# %% [markdown]
# #Poisson#

# %%
from scipy.stats import poisson

# Parámetros de la distribución de Poisson
media_accidentes = 2

# Parte 1: Probabilidad de que no haya accidentes en 1 semana
probabilidad_0_accidentes = poisson.pmf(0, media_accidentes)

print("1. Probabilidad de que no haya accidentes en 1 semana:", probabilidad_0_accidentes)

# Parte 2: Probabilidad de que a lo sumo haya tres accidentes en 2 semanas
# Convertimos la media a una media para 2 semanas
media_2_semanas = media_accidentes * 2

# Calculamos la probabilidad acumulada hasta 3 accidentes en 2 semanas
probabilidad_3_o_menos_accidentes = poisson.cdf(3, media_2_semanas)

print("2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas:", probabilidad_3_o_menos_accidentes)
# Out:
# 1. Probabilidad de que no haya accidentes en 1 semana: 0.1353352832366127
# 2. Probabilidad de que a lo sumo haya tres accidentes en 2 semanas: 0.43347012036670896

# %%
from scipy.stats import poisson

# Parámetros de la distribución de Poisson
media_muertes = 5000 * 0.001 # 5000 hombres con una probabilidad de muerte de 0.001

# Número de reclamaciones
x = 4

# Calcular la probabilidad de que la compañía tenga que pagar 4 reclamaciones en un año determinado
probabilidad_4_reclamaciones = poisson.pmf(x, media_muertes)

print("La probabilidad de que la compañía tenga que pagar 4 reclamaciones es de:",
      probabilidad_4_reclamaciones)
# Out:
# La probabilidad de que la compañía tenga que pagar 4 reclamaciones es DE: 0.17546736976785063

# %%
from scipy.stats import poisson

# Parámetros de la distribución de Poisson
media_muertes = 5000 * 0.001 # 5000 hombres con una probabilidad de muerte de 0.001

# Número de reclamaciones
x = 4

# Calcular la probabilidad de que la compañía tenga que pagar 4 reclamaciones en un año determinado
probabilidad_4_reclamaciones = poisson.pmf(x, media_muertes)

print("La probabilidad de que la compañía tenga que pagar 4 reclamaciones es de:",
      probabilidad_4_reclamaciones)
# Out:
# La probabilidad de que la compañía tenga que pagar 4 reclamaciones es DE: 0.17546736976785063
