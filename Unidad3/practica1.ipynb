# %% [markdown]
# <a href="https://colab.research.google.com/github/Katia1697/PyE/blob/main/Unidad3/practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import binom

#Parametros
n = 3 # numero de volados (ensayos)
p = 0.5 #Probabilidad de obtener sol en cada volado (exito)

# Valores de X
x_values = [0, 1, 2, 3]

# Calcular la PMF (Funcion de Masa de Probabilidad) para cada valor de x
pmf_values = binom.pmf(x_values, n, p)

# imprimir los valores
for x, pmf in zip(x_values, pmf_values):
  print(f'P(X={x}) = {pmf:.3f}')
# Out:
# P(X=0) = 0.125
# P(X=1) = 0.375
# P(X=2) = 0.375
# P(X=3) = 0.125

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

#Parametros
n = 3 #numero de volados (ensayos)
p = 0.5 #Probabilidad de obtener sol en cada volado (exito)

#Distribucion binomial
x = np.arange(0, n+1)
pfm = binom.pmf(x, n, p)

#Grafica
plt.bar(x, pmf)
plt.xlabel('numero de soles')
plt.ylabel('Probabilidad')
plt.title('Distribucion Binomial: Numero de soles en 3 volados de una moneda justa')
plt.show()
